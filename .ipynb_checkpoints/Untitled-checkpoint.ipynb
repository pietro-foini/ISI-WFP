# %%
import numpy as np
import pandas as pd

# %%
def next_datetime_point(date):
    next_date = datetime.date(date.year, date.month, date.day) + relativedelta.relativedelta(months = 1)
    next_date = next_date + relativedelta.relativedelta(day = 31)
    return pd.Timestamp(next_date)

# %%
else:
    dates_to_forecast = list()
    date = df.index[-1]
    for i in range(n_out):
        next_date = next_datetime_point(date)
        dates_to_forecast.append(next_date)
        date = next_date 
    dates_to_forecast = pd.Index(dates_to_forecast, name = "Datetime")

# %%
s1 = pd.Series([.1, .0, .5, .1])

# %%
df = pd.DataFrame([(.2, .3), (.0, .6), (.6, .0), (.2, .1)],columns=['dogs', 'cats'])

# %%
s1.corr(s2, method=histogram_intersection)
# Out:
# 0.2

# %%
1/8
# Out:
# 0.125

# %%
import math

a=0.25*math.log(0.25) + 0.25*math.log(0.25) + 0.125*math.log(0.125) + 0.125*math.log(0.125) + 0.125*math.log(0.125) + 0.125*math.log(0.125)
a=-a/math.log(math.factorial(3))

a
# Out:
# 0.967132018086354

# %%
histogram_intersection(df.dogs.values, df.cats.values)
# Out:
# 0.25

# %%
df.corr(method=histogram_intersection)
# Out:
#       dogs  cats
# dogs  1.00  0.25
# cats  0.25  1.00

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection

N = 10
M = 11
ylabels = ["".join(np.random.choice(list("PQRSTUVXYZ"), size=7)) for _ in range(N)]
xlabels = ["".join(np.random.choice(list("ABCDE"), size=3)) for _ in range(M)]

x, y = np.meshgrid(np.arange(M), np.arange(N))
s = np.random.randint(0, 180, size=(N,M))
c = np.random.rand(N, M)-0.5

fig, ax = plt.subplots()

R = s/s.max()/2
circles = [plt.Circle((j,i), radius=r) for r, j, i in zip(R.flat, x.flat, y.flat)]
col = PatchCollection(circles, array=c.flatten(), cmap="RdYlGn")
ax.add_collection(col)

ax.set(xticks=np.arange(M), yticks=np.arange(N),
       xticklabels=xlabels, yticklabels=ylabels)
ax.set_xticks(np.arange(M+1)-0.5, minor=True)
ax.set_yticks(np.arange(N+1)-0.5, minor=True)
ax.grid(which='minor')

fig.colorbar(col)
plt.show()

# %%
c
# Out:
# array([[ 0.39594977, -0.43081074, -0.13591885, -0.41057585, -0.37249678,
#         -0.36069709,  0.44992788,  0.39027326,  0.31926007, -0.11531859,
#          0.01929232],
#        [-0.30453551,  0.43664323,  0.30258681, -0.01468949,  0.17635309,
#          0.26762719, -0.38776443,  0.01768572,  0.06399901,  0.46096835,
#          0.39873161],
#        [-0.02410748, -0.02499857, -0.02961202,  0.37719398, -0.3453146 ,
#          0.39204229, -0.19411782, -0.36853576,  0.08439811,  0.11460802,
#          0.23776475],
#        [-0.43476558,  0.47535811,  0.39879668,  0.10807201,  0.26131104,
#         -0.08559964,  0.0725044 ,  0.43611121, -0.41565163,  0.42234401,
#         -0.32564393],
#        [ 0.1479938 ,  0.2808025 , -0.06533231, -0.44603604,  0.15655754,
#         -0.30270283, -0.37185625,  0.17030595, -0.00738703,  0.05709098,
#         -0.4575864 ],
#        [ 0.22110377, -0.37896824,  0.17201444, -0.14211634, -0.45248762,
# ...
