# %% [markdown]
# # Variance Inflation Factor

# %%
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
COUNTRY = "Yemen"

# %%
PATH_TO_DATA_FOLDER = "../Dataset time-series/output_data/" + COUNTRY + "/"

# %% [markdown]
# ## Time-series dataset

# %%
# Load the time-series data (daily interpolation).
df = pd.read_csv(PATH_TO_DATA_FOLDER + COUNTRY + ".csv", header = [0, 1], index_col = 0)
df.index.name = "Datetime"
df.index = pd.to_datetime(df.index)
freq = "D"
df.index.freq = freq

# %%
df.columns.get_level_values(1).unique()
# Out:
# Index(['1 Month Anomaly Rainfalls (%)', '3 Months Anomaly Rainfalls (%)',
#        'Area', 'Code', 'FCG', 'Fatalities', 'Lat', 'Lon', 'NDVI',
#        'NDVI Anomaly', 'Population', 'Price cereals and tubers',
#        'Rainfalls (mm)', 'Ramadan', 'Waterways', 'rCSI'],
#       dtype='object', name='Indicator')

# %%
# Consider only some indicators for the analysis with Spearman correlation.
INDICATORS_TO_CONSIDER = ["FCG", "1 Month Anomaly Rainfalls (%)", "3 Months Anomaly Rainfalls (%)", 
                          "NDVI", "Price cereals and tubers", "Fatalities", "NDVI Anomaly", 
                          "rCSI", "Rainfalls (mm)"] # "Exchange rate"

df = df.loc[:, df.columns.get_level_values(1).isin(INDICATORS_TO_CONSIDER)]
df.head()
# Out:
# AdminStrata                         Abyan                                     \
# Indicator   1 Month Anomaly Rainfalls (%) 3 Months Anomaly Rainfalls (%) FCG
# Datetime
# 2018-01-01                            NaN                            NaN NaN
# 2018-01-02                            NaN                            NaN NaN
# 2018-01-03                            NaN                            NaN NaN
# 2018-01-04                            NaN                            NaN NaN
# 2018-01-05                            NaN                            NaN NaN
#
# AdminStrata                                                        \
# Indicator   Fatalities NDVI NDVI Anomaly Price cereals and tubers
# Datetime
# 2018-01-01         NaN  NaN          NaN                      NaN
# 2018-01-02         NaN  NaN          NaN                      NaN
# 2018-01-03         NaN  NaN          NaN                      NaN
# 2018-01-04         NaN  NaN          NaN                      NaN
# 2018-01-05         NaN  NaN          NaN                      NaN
#
# AdminStrata                                              Aden  ... Shabwah  \
# Indicator   Rainfalls (mm) rCSI 1 Month Anomaly Rainfalls (%)  ...    rCSI
# Datetime                                                       ...
# 2018-01-01             NaN  NaN                           NaN  ...     NaN
# 2018-01-02             NaN  NaN                           NaN  ...     NaN
# 2018-01-03             NaN  NaN                           NaN  ...     NaN
# 2018-01-04             NaN  NaN                           NaN  ...     NaN
# 2018-01-05             NaN  NaN                           NaN  ...     NaN
#
# AdminStrata                         Taizz                                     \
# Indicator   1 Month Anomaly Rainfalls (%) 3 Months Anomaly Rainfalls (%) FCG
# Datetime
# 2018-01-01                            NaN                            NaN NaN
# 2018-01-02                            NaN                            NaN NaN
# 2018-01-03                            NaN                            NaN NaN
# 2018-01-04                            NaN                            NaN NaN
# 2018-01-05                            NaN                            NaN NaN
#
# AdminStrata                                                        \
# Indicator   Fatalities NDVI NDVI Anomaly Price cereals and tubers
# Datetime
# 2018-01-01         NaN  NaN          NaN                      NaN
# 2018-01-02         NaN  NaN          NaN                      NaN
# 2018-01-03         NaN  NaN          NaN                      NaN
# 2018-01-04         NaN  NaN          NaN                      NaN
# 2018-01-05         NaN  NaN          NaN                      NaN
#
# AdminStrata
# Indicator   Rainfalls (mm) rCSI
# Datetime
# 2018-01-01             NaN  NaN
# 2018-01-02             NaN  NaN
# 2018-01-03             NaN  NaN
# 2018-01-04             NaN  NaN
# 2018-01-05             NaN  NaN
#
# [5 rows x 180 columns]

# %%
df.rename({"1 Month Anomaly Rainfalls (%)": "omonthrainfalls", 
           "3 Months Anomaly Rainfalls (%)": "tmonthrainfalls", 
           "Exchange rate": "exchange", 
           "FCG": "fcg",
           "Fatalities": "fatalities",
           "NDVI Anomaly": "ndvianonaly",
           "NDVI": "ndvi",
           "Price cereals and tubers": "pricecereals", 
           "Rainfalls (mm)": "rainfalls", 
           "rCSI": "rcsi"}, axis = 1, level = 1, inplace = True)

# %%
df.drop(["tmonthrainfalls", "ndvianonaly"], axis = 1, level = 1, inplace = True)

# %%
def vif_func(group):
    group = group[group.name]

    # Gather features.
    features = "+".join(group.columns[group.columns != "fcg"])

    # Get y and X dataframes based on this regression.
    y, X = dmatrices('fcg ~' + features, group, return_type = "dataframe")
    
    # For each X, calculate VIF and save in dataframe.
    vif = pd.DataFrame()
    vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif["features"] = X.columns
    
    return vif.set_index("features")

vif_factor = df.groupby(axis = 1, level = 0).apply(vif_func) 
vif_factor.head()
# Out:
# AdminStrata           Abyan        Aden    Al Bayda  Al Dhale'e Al Hudaydah  \
#                  VIF Factor  VIF Factor  VIF Factor  VIF Factor  VIF Factor
# features
# Intercept        154.219070  155.882248  156.606053  135.234363  132.917721
# omonthrainfalls    2.011619    2.149107    1.829229    1.484573    2.786350
# fatalities         1.144230    1.065755    1.157739    1.378517    1.206310
# ndvi               1.902154    1.261148    1.287974    1.381680    1.363780
# pricecereals       1.662246    1.504573    1.344410    1.246448    1.303454
#
# AdminStrata          Al Jawf  Al Maharah   Al Mahwit Amanat Al Asimah  \
#                   VIF Factor  VIF Factor  VIF Factor       VIF Factor
# features
# Intercept        3744.841153  576.269456  304.372927       189.565234
# omonthrainfalls     3.553919    1.190789    2.157270         3.454453
# fatalities          1.857995    1.132893    1.552660         1.103857
# ndvi                1.801562    1.195541    1.049612         1.149711
# pricecereals        3.729532    1.064232    1.435583         1.066678
#
# AdminStrata           Amran      Dhamar      Hajjah         Ibb        Lahj  \
#                  VIF Factor  VIF Factor  VIF Factor  VIF Factor  VIF Factor
# features
# Intercept        206.682892  349.263969  323.181971  267.035297  112.338926
# omonthrainfalls    3.276343    2.615615    2.092428    1.525049    2.399057
# fatalities         1.116083    1.198522    1.721311    1.173521    1.139589
# ndvi               1.232687    1.228459    1.362234    1.346473    1.706544
# pricecereals       1.199403    1.187096    1.422791    1.143368    1.659450
#
# AdminStrata           Marib      Raymah      Sa'ada      Sana'a     Shabwah  \
#                  VIF Factor  VIF Factor  VIF Factor  VIF Factor  VIF Factor
# features
# Intercept        492.333265  226.012704  219.641681  241.404640  414.443246
# omonthrainfalls    3.278057    1.866014    1.933753    4.292737    1.814281
# fatalities         1.899539    1.253706    1.735263    1.396514    1.397927
# ndvi               1.271949    1.180635    1.241806    1.166137    1.853732
# pricecereals       1.719281    1.570661    1.531005    1.373119    2.239808
#
# AdminStrata           Taizz
#                  VIF Factor
# features
# Intercept        174.332038
# omonthrainfalls    1.547866
# fatalities         1.328861
# ndvi               1.316029
# pricecereals       1.144534

# %%
vif_factor.mean(axis = 1)
# Out:
# features
# Intercept          428.828943
# omonthrainfalls      2.362925
# fatalities           1.348040
# ndvi                 1.364992
# pricecereals         1.527383
# rainfalls            2.397046
# rcsi                 1.287871
# dtype: float64
