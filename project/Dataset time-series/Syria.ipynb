# %%
import pandas as pd
import numpy as np

# %%
# Add the python path to the folder containing some useful custom packages.
import sys
sys.path.insert(0, "../packages/")
from TsIP.TsIP import TsIP
from tools import find_multiple_sets

# %% [markdown]
# # Syria

# %% [markdown]
# I create the dataset of time-series of the Syria country.

# %%
PATH_TO_SAVE = "./data/Syria/"

# %% [markdown]
# ## Data sources

# %% [markdown]
# For more details regarding each single data source see the folder *Data Sources*.

# %%
PATH_TO_DATA_FOLDER = "../Data Sources/"

# %% [markdown]
#     - Food Consumption Score:

# %%
# Load the data of the fcs indicator released by wfp.
fcs = pd.read_csv(PATH_TO_DATA_FOLDER + "Food Consumption Score (FCS)/output_timeseries/Syria/wfp_fcs-no-nan.csv", header = [0, 1], index_col = 0)
fcs.index.name = "Datetime"
fcs.index = pd.to_datetime(fcs.index)
freq = "D"
fcs.index.freq = freq

# %% [markdown]
#     - Reduced Coping Strategy Index

# %%
# Load the the data of the rcsi indicator released by wfp.
rcsi = pd.read_csv(PATH_TO_DATA_FOLDER + "Reduced Coping Strategy Index (rCSI)/output_timeseries/Syria/wfp_rcsi-no-nan.csv", header = [0, 1], index_col = 0)
rcsi.index.name = "Datetime"
rcsi.index = pd.to_datetime(rcsi.index)
freq = "D"
rcsi.index.freq = freq

# %% [markdown]
#     - Rainfall:

# %%
# Load the data of rainfall indicator released by wfp.
rainfall = pd.read_csv(PATH_TO_DATA_FOLDER + "Rainfall & Vegetation/output_timeseries/Syria/wfp_rainfall_SvyWindow.csv", header = [0, 1], index_col = 0)
rainfall.index.name = "Datetime"
rainfall.index = pd.to_datetime(rainfall.index)
freq = "D"
rainfall.index.freq = freq

# %% [markdown]
#     - NDVI:

# %%
# Load the data of vegetation indicator released by wfp.
NDVI = pd.read_csv(PATH_TO_DATA_FOLDER + "Rainfall & Vegetation/output_timeseries/Syria/wfp_NDVI_SvyWindow.csv", header = [0, 1], index_col = 0)
NDVI.index.name = "Datetime"
NDVI.index = pd.to_datetime(NDVI.index)
freq = "D"
NDVI.index.freq = freq

# %% [markdown]
#     - Conflict:

# %%
# Load the data of conflicts indicator released by ACLED.
conflict = pd.read_csv(PATH_TO_DATA_FOLDER + "Conflicts/output_timeseries/Syria/wfp_conflicts_sum_event_SvyWindow.csv", header = [0, 1], index_col = 0)
conflict.index.name = "Datetime"
conflict.index = pd.to_datetime(conflict.index)
freq = "D"
conflict.index.freq = freq

# %% [markdown]
#     - Market price:

# %%
# Load the data of market prices indicator released by wfp.
price = pd.read_csv(PATH_TO_DATA_FOLDER + "Market Prices/output_timeseries/Syria/wfp_relevant_market_price-exchange-rate-cereals.csv", header = [0, 1], index_col = 0)
price.index.name = "Datetime"
price.index = pd.to_datetime(price.index)
freq = "D"
price.index.freq = freq

# %% [markdown]
#     - Population:

# %%
# Load the data of population released by wfp.
population = pd.read_csv(PATH_TO_DATA_FOLDER + "Population/output_timeseries/Syria/wfp_population.csv", header = [0, 1], index_col = 0)
population.index.name = "Datetime"
population.index = pd.to_datetime(population.index)
freq = "D"
population.index.freq = freq

# %% [markdown]
#     - Coordinates:

# %%
# Load the data of coordination.
coordinates = pd.read_csv(PATH_TO_DATA_FOLDER + "Coordinates/output_timeseries/Syria/wfp_coordinates.csv", header = [0, 1], index_col = 0)
coordinates.index.name = "Datetime"
coordinates.index = pd.to_datetime(coordinates.index)
freq = "D"
coordinates.index.freq = freq

# %% [markdown]
#     - Ramadan:

# %%
# Load the data of ramadan.
ramadan = pd.read_csv(PATH_TO_DATA_FOLDER + "Ramadan/output_timeseries/Syria/wfp_ramadan_SvyWindow.csv", header = [0, 1], index_col = 0)
ramadan.index.name = "Datetime"
ramadan.index = pd.to_datetime(ramadan.index)
freq = "D"
ramadan.index.freq = freq

# %%
# Create the full dataset.
df = pd.concat([fcs, rcsi, rainfall, conflict, NDVI, price, population, coordinates, ramadan], axis = 1, levels = 0).sort_index(axis = 1)

# %%
# Define parameters.
TEST_SIZE = 30
FREQ = df.index.freq

# %%
# Create the no nan values.
df = df.dropna()
df
# Out:
# AdminStrata                   Al-Hasakeh                                \
# Indicator   1 Month Anomaly (%) Rainfall 3 Months Anomaly (%) Rainfall
# Datetime
# 2018-08-31                    310.000000                    530.373455
# 2018-09-01                    310.004999                    517.912533
# 2018-09-02                    310.009998                    505.451610
# 2018-09-03                    310.014997                    492.990688
# 2018-09-04                    310.019996                    480.529765
# ...                                  ...                           ...
# 2020-06-26                    316.647450                    326.644497
# 2020-06-27                    314.806750                    324.402006
# 2020-06-28                    312.966050                    322.159514
# 2020-06-29                    311.125351                    319.917023
# 2020-06-30                    309.284651                    317.674531
#
# AdminStrata                                                                 \
# Indicator   Cereals and tubers Exchange rate (USD/LCU)        FCS Fatality
# Datetime
# 2018-08-31            0.044685                0.011538  35.854830     93.0
# 2018-09-01            0.044812                0.011688  35.854830     93.0
# 2018-09-02            0.044938                0.011838  35.517870     63.0
# 2018-09-03            0.045065                0.011987  34.914770     73.0
# 2018-09-04            0.045192                0.012137  33.791150     73.0
# ...                        ...                     ...        ...      ...
# 2020-06-26            0.510744                0.789744  31.594760     38.0
# 2020-06-27            0.512258                0.800214  32.392750     37.0
# 2020-06-28            0.513773                0.810684  32.155860     36.0
# 2020-06-29            0.515287                0.821154  32.155855     38.0
# 2020-06-30            0.516801                0.831624  33.230895     38.0
#
# AdminStrata                                                ...  \
# Indicator          Lat        Lon NDVI Anomaly Population  ...
# Datetime                                                   ...
# 2018-08-31   36.491475  40.907354  2798.030410  1033316.0  ...
# 2018-09-01   36.491475  40.907354  2795.421873  1033316.0  ...
# 2018-09-02   36.491475  40.907354  2793.008933  1033316.0  ...
# 2018-09-03   36.491475  40.907354  2790.791589  1033316.0  ...
# 2018-09-04   36.491475  40.907354  2788.769841  1033316.0  ...
# ...                ...        ...          ...        ...  ...
# 2020-06-26   36.491475  40.907354  3779.422355  1033316.0  ...
# 2020-06-27   36.491475  40.907354  3767.319854  1033316.0  ...
# 2020-06-28   36.491475  40.907354  3756.045933  1033316.0  ...
# 2020-06-29   36.491475  40.907354  3745.600593  1033316.0  ...
# 2020-06-30   36.491475  40.907354  3735.983831  1033316.0  ...
#
# AdminStrata                 Tartous                                            \
# Indicator   Exchange rate (USD/LCU)        FCS Fatality        Lat        Lon
# Datetime
# 2018-08-31                 0.011325  20.384620      0.0  34.959426  36.077933
# 2018-09-01                 0.011460  20.784310      0.0  34.959426  36.077933
# 2018-09-02                 0.011595  21.388220      0.0  34.959426  36.077933
# 2018-09-03                 0.011731  20.429360      0.0  34.959426  36.077933
# 2018-09-04                 0.011866  18.261500      1.0  34.959426  36.077933
# ...                             ...        ...      ...        ...        ...
# 2020-06-26                 0.829772  25.357310      0.0  34.959426  36.077933
# 2020-06-27                 0.842415  25.357310      0.0  34.959426  36.077933
# 2020-06-28                 0.855057  25.505720      0.0  34.959426  36.077933
# 2020-06-29                 0.867699  26.512013      0.0  34.959426  36.077933
# 2020-06-30                 0.880342  26.186579      0.0  34.959426  36.077933
#
# AdminStrata
# Indicator   NDVI Anomaly Population Rainfall (mm) Ramadan       rCSI
# Datetime
# 2018-08-31   3552.406455   831296.0        0.1507     0.0  25.961540
# 2018-09-01   3554.354567   831296.0        0.5932     0.0  26.470590
# 2018-09-02   3556.169251   831296.0        1.0357     0.0  27.239710
# 2018-09-03   3557.850509   831296.0        1.4782     0.0  25.450140
# 2018-09-04   3559.398340   831296.0        1.9207     0.0  26.296570
# ...                  ...        ...           ...     ...        ...
# 2020-06-26   3572.613161   831296.0        5.6705     0.0  36.422310
# 2020-06-27   3577.331787   831296.0        5.0389     0.0  36.422310
# 2020-06-28   3582.129573   831296.0        4.4073     0.0  38.698330
# 2020-06-29   3587.006519   831296.0        3.7757     0.0  38.939519
# 2020-06-30   3591.962624   831296.0        3.1441     0.0  38.461538
#
# [670 rows x 169 columns]

# %%
PREDICTORS = df.columns.get_level_values(1).unique()
PREDICTORS
# Out:
# Index(['1 Month Anomaly (%) Rainfall', '3 Months Anomaly (%) Rainfall',
#        'Cereals and tubers', 'Exchange rate (USD/LCU)', 'FCS', 'Fatality',
#        'Lat', 'Lon', 'NDVI Anomaly', 'Population', 'Rainfall (mm)', 'Ramadan',
#        'rCSI'],
#       dtype='object', name='Indicator')

# %%
# Remove provinces that not have all the indicators.
provinces_to_remove = list()
for province in df.columns.get_level_values(0).unique():
    if not all(item in df[[province]].columns.get_level_values(1).unique() for item in PREDICTORS):
        provinces_to_remove.append(province)

# %%
df.drop(provinces_to_remove, axis = 1, level = 0, inplace = True)
df
# Out:
# AdminStrata                   Al-Hasakeh                                \
# Indicator   1 Month Anomaly (%) Rainfall 3 Months Anomaly (%) Rainfall
# Datetime
# 2018-08-31                    310.000000                    530.373455
# 2018-09-01                    310.004999                    517.912533
# 2018-09-02                    310.009998                    505.451610
# 2018-09-03                    310.014997                    492.990688
# 2018-09-04                    310.019996                    480.529765
# ...                                  ...                           ...
# 2020-06-26                    316.647450                    326.644497
# 2020-06-27                    314.806750                    324.402006
# 2020-06-28                    312.966050                    322.159514
# 2020-06-29                    311.125351                    319.917023
# 2020-06-30                    309.284651                    317.674531
#
# AdminStrata                                                                 \
# Indicator   Cereals and tubers Exchange rate (USD/LCU)        FCS Fatality
# Datetime
# 2018-08-31            0.044685                0.011538  35.854830     93.0
# 2018-09-01            0.044812                0.011688  35.854830     93.0
# 2018-09-02            0.044938                0.011838  35.517870     63.0
# 2018-09-03            0.045065                0.011987  34.914770     73.0
# 2018-09-04            0.045192                0.012137  33.791150     73.0
# ...                        ...                     ...        ...      ...
# 2020-06-26            0.510744                0.789744  31.594760     38.0
# 2020-06-27            0.512258                0.800214  32.392750     37.0
# 2020-06-28            0.513773                0.810684  32.155860     36.0
# 2020-06-29            0.515287                0.821154  32.155855     38.0
# 2020-06-30            0.516801                0.831624  33.230895     38.0
#
# AdminStrata                                                ...  \
# Indicator          Lat        Lon NDVI Anomaly Population  ...
# Datetime                                                   ...
# 2018-08-31   36.491475  40.907354  2798.030410  1033316.0  ...
# 2018-09-01   36.491475  40.907354  2795.421873  1033316.0  ...
# 2018-09-02   36.491475  40.907354  2793.008933  1033316.0  ...
# 2018-09-03   36.491475  40.907354  2790.791589  1033316.0  ...
# 2018-09-04   36.491475  40.907354  2788.769841  1033316.0  ...
# ...                ...        ...          ...        ...  ...
# 2020-06-26   36.491475  40.907354  3779.422355  1033316.0  ...
# 2020-06-27   36.491475  40.907354  3767.319854  1033316.0  ...
# 2020-06-28   36.491475  40.907354  3756.045933  1033316.0  ...
# 2020-06-29   36.491475  40.907354  3745.600593  1033316.0  ...
# 2020-06-30   36.491475  40.907354  3735.983831  1033316.0  ...
#
# AdminStrata                 Tartous                                            \
# Indicator   Exchange rate (USD/LCU)        FCS Fatality        Lat        Lon
# Datetime
# 2018-08-31                 0.011325  20.384620      0.0  34.959426  36.077933
# 2018-09-01                 0.011460  20.784310      0.0  34.959426  36.077933
# 2018-09-02                 0.011595  21.388220      0.0  34.959426  36.077933
# 2018-09-03                 0.011731  20.429360      0.0  34.959426  36.077933
# 2018-09-04                 0.011866  18.261500      1.0  34.959426  36.077933
# ...                             ...        ...      ...        ...        ...
# 2020-06-26                 0.829772  25.357310      0.0  34.959426  36.077933
# 2020-06-27                 0.842415  25.357310      0.0  34.959426  36.077933
# 2020-06-28                 0.855057  25.505720      0.0  34.959426  36.077933
# 2020-06-29                 0.867699  26.512013      0.0  34.959426  36.077933
# 2020-06-30                 0.880342  26.186579      0.0  34.959426  36.077933
#
# AdminStrata
# Indicator   NDVI Anomaly Population Rainfall (mm) Ramadan       rCSI
# Datetime
# 2018-08-31   3552.406455   831296.0        0.1507     0.0  25.961540
# 2018-09-01   3554.354567   831296.0        0.5932     0.0  26.470590
# 2018-09-02   3556.169251   831296.0        1.0357     0.0  27.239710
# 2018-09-03   3557.850509   831296.0        1.4782     0.0  25.450140
# 2018-09-04   3559.398340   831296.0        1.9207     0.0  26.296570
# ...                  ...        ...           ...     ...        ...
# 2020-06-26   3572.613161   831296.0        5.6705     0.0  36.422310
# 2020-06-27   3577.331787   831296.0        5.0389     0.0  36.422310
# 2020-06-28   3582.129573   831296.0        4.4073     0.0  38.698330
# 2020-06-29   3587.006519   831296.0        3.7757     0.0  38.939519
# 2020-06-30   3591.962624   831296.0        3.1441     0.0  38.461538
#
# [670 rows x 130 columns]

# %%
# Plot time-series.
TsIP(df).interactive_plot_df(matplotlib = False, style = "lines", first_last_valid_index_group = True)
# Out:
# interactive(children=(ToggleButtons(description='AdminStrata', options=('Al-Hasakeh', 'Aleppo', 'As-Sweida', '…

# %%
PROVINCES = df.columns.get_level_values(0).unique()
PROVINCES
# Out:
# Index(['Al-Hasakeh', 'Aleppo', 'As-Sweida', 'Damascus', 'Dar'a', 'Hama',
#        'Homs', 'Lattakia', 'Rural Damascus', 'Tartous'],
#       dtype='object', name='AdminStrata')

# %%
PREDICTORS = df.columns.get_level_values(1).unique()
PREDICTORS
# Out:
# Index(['1 Month Anomaly (%) Rainfall', '3 Months Anomaly (%) Rainfall',
#        'Cereals and tubers', 'Exchange rate (USD/LCU)', 'FCS', 'Fatality',
#        'Lat', 'Lon', 'NDVI Anomaly', 'Population', 'Rainfall (mm)', 'Ramadan',
#        'rCSI'],
#       dtype='object', name='Indicator')

# %% [markdown]
# ## Create training sets and test sets

# %%
# Define the maximum number of lags to create training points.
MAX_INPUT = 130 # days

# %%
# Define some initial dates of the test sets.
# They are chosen in order to have at least MAX_INPUT + TEST_SIZE points of difference between each others.
test_dates = ["2019-03-16", "2019-10-23", "2020-06-01"]
test_dates = [pd.date_range(pd.Timestamp(x, freq = FREQ), pd.Timestamp(x, freq = FREQ) + (TEST_SIZE-1)*FREQ, freq = "D") for x in test_dates]

# %%
# Merge the test sets index.
test_sets_index = np.concatenate(test_dates)

# %%
# Create test and training sets dataframes of the fcs indicator.
df_train = df.copy()
fcs_train = fcs.copy()
fcs_test = fcs.copy()

df_train.loc[df_train.index.isin(test_sets_index)] = np.nan
fcs_train.loc[fcs_train.index.isin(test_sets_index)] = np.nan
fcs_test.loc[~fcs_test.index.isin(test_sets_index)] = np.nan

# %%
# Plot time-series.
TsIP(fcs_test, fcs_train).interactive_plot_df(title = "FCS training and test sets", matplotlib = False, style = "lines", comparison = True)
# Out:
# interactive(children=(RadioButtons(description='Select:', options=('Time-series', 'Missing values'), value='Ti…

# %%
# Plot time-series.
TsIP(df_train).interactive_plot_df(title = "Training sets", matplotlib = False, style = "lines")
# Out:
# interactive(children=(ToggleButtons(description='AdminStrata', options=('Al-Hasakeh', 'Aleppo', 'As-Sweida', '…

# %%
# Get the training and test sets.
TRAIN_NORMALIZED_SETS = find_multiple_sets(df_train)
TEST_TARGET_SETS = find_multiple_sets(fcs_test)

# %% [markdown]
# ## Smoothed data

# %%
# This features will not be modified.
static_indicators = ["Lat", "Lon", "Population", "Ramadan"]

# %%
from scipy.signal import savgol_filter

def smooth(serie):
    if serie.name[1] in static_indicators:
        return serie
    
    # Find the multiple sets.
    sets = find_multiple_sets(serie)
    # Smooth the sets.
    for set_ in sets:
        smooth_set = savgol_filter(set_, 31, 7)
        serie.loc[set_.index] = smooth_set

    return serie

df_train_smooth = df_train.copy().apply(smooth)

# %%
# Comparison plot time-series.
TsIP(df_train, df_train_smooth).interactive_plot_df(matplotlib = False, style = "lines", first_last_valid_index_group = True, comparison = True)
# Out:
# interactive(children=(ToggleButtons(description='AdminStrata', options=('Al-Hasakeh', 'Aleppo', 'As-Sweida', '…

# %% [markdown]
# ## Save datasets

# %%
# Save the datasets.
df_train.to_csv(PATH_TO_SAVE + "train.csv", index_label = False)
df_train_smooth.to_csv(PATH_TO_SAVE + "train_smooth.csv", index_label = False)

# %%
# Save the datasets.
fcs_test.to_csv(PATH_TO_SAVE + "test_target.csv", index_label = False)
fcs.to_csv(PATH_TO_SAVE + "all_target.csv", index_label = False)

# %%
df.to_csv(PATH_TO_SAVE + "all_train.csv", index_label = False)
