# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Add the python path to the folder containing some useful custom packages.
import sys
sys.path.insert(0, "../../packages/")
from TsIP.TsIP import TsIP
from tools import find_multiple_sets
from LagsCreator.LagsCreator import LagsCreator

# %% [markdown]
# ## Dataset

# %%
COUNTRY = "Yemen"

# %%
PATH_TO_DATA_FOLDER = "../../Dataset time-series/data/" + COUNTRY + "/"

# %%
# Load the dataset of the training sets.
train = pd.read_csv(PATH_TO_DATA_FOLDER + "train_smooth.csv", header = [0, 1], index_col = 0)
train.index.name = "Datetime"
train.index = pd.to_datetime(train.index)
freq = "D"
train.index.freq = freq

# %%
# Load the dataset of the test sets.
test = pd.read_csv(PATH_TO_DATA_FOLDER + "test_target.csv", header = [0, 1], index_col = 0)
test.index.name = "Datetime"
test.index = pd.to_datetime(test.index)
freq = "D"
test.index.freq = freq

# %%
# Load the dataset of the whole time-series of the fcs indicator.
target = pd.read_csv(PATH_TO_DATA_FOLDER + "all_target.csv", header = [0, 1], index_col = 0)
target.index.name = "Datetime"
target.index = pd.to_datetime(target.index)
freq = "D"
target.index.freq = freq

# %%
TEST_SIZE = 30
FREQ = train.index.freq

# %%
TRAIN = train.copy()

# %%
PROVINCES = TRAIN.columns.get_level_values(0).unique()
PROVINCES
# Out:
# Index(['Abyan', 'Aden', 'Al Bayda', 'Al Dhale'e', 'Al Hudaydah', 'Al Jawf',
#        'Al Maharah', 'Al Mahwit', 'Amanat Al Asimah', 'Amran', 'Dhamar',
#        'Hajjah', 'Ibb', 'Lahj', 'Marib', 'Raymah', 'Sa'ada', 'Sana'a',
#        'Shabwah', 'Taizz'],
#       dtype='object', name='AdminStrata')

# %%
PREDICTORS = TRAIN.columns.get_level_values(1).unique()
PREDICTORS
# Out:
# Index(['1 Month Anomaly (%) Rainfall', '3 Months Anomaly (%) Rainfall',
#        'Cereals and tubers', 'Exchange rate (USD/LCU)', 'FCS', 'Fatality',
#        'Lat', 'Lon', 'NDVI Anomaly', 'Population', 'Rainfall (mm)', 'Ramadan',
#        'rCSI'],
#       dtype='object', name='Indicator')

# %%
# Get the training and test sets.
TRAIN_NORMALIZED_SETS = find_multiple_sets(train)
TEST_TARGET_SETS = find_multiple_sets(test)

# %% [markdown]
# ## Training & Validation

# %%
lags_dict = dict()
# Define lags for each indicator.
lags_dict["1 Month Anomaly (%) Rainfall"] = 2
lags_dict["3 Months Anomaly (%) Rainfall"] = 1
lags_dict["Cereals and tubers"] = 2
lags_dict["Exchange rate (USD/LCU)"] = 5
lags_dict["FCS"] = 2
lags_dict["Fatality"] = 2
lags_dict["NDVI Anomaly"] = 2
lags_dict["Rainfall (mm)"] = 2
lags_dict["rCSI"] = 2
lags_dict["Lat"] = 0
lags_dict["Lon"] = 0
lags_dict["Population"] = 0
lags_dict["Ramadan"] = 1

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
val_losses_h = dict()

# %%
for h in range(TEST_SIZE):
    print("Training and validation for prediction horizon: %d" % (h+1))
    X_train_list, y_train_list, X_val_list, y_val_list = list(), list(), list(), list()
    for train_normalized in TRAIN_NORMALIZED_SETS:
        # Create training and validation samples.  
        for PROVINCE in PROVINCES:
            creator = LagsCreator(train_normalized[[PROVINCE]], lags_dictionary = lags_dict, target = "FCS")
            X_train, y_train, X_val, y_val, _ = creator.to_supervised(n_out = TEST_SIZE, single_step = True, h = h+1, return_dataframe = True,
                                                                      feature_time = True, validation = True, return_single_level = True, 
                                                                      dtype = np.float32)
            X_train_list.append(X_train)
            y_train_list.append(y_train)
            X_val_list.append(X_val)
            y_val_list.append(y_val)  

    X_train = pd.concat(X_train_list).reset_index(drop = True)
    y_train = pd.concat(y_train_list).reset_index(drop = True)
    
    # Train the model.
    model = xgb.XGBRegressor(n_estimators = 100, objective = "reg:squarederror")   
    model.fit(X_train, y_train)  
    
    X_val = pd.concat(X_val_list).reset_index(drop = True)
    y_val = pd.concat(y_val_list).reset_index(drop = True)
    
    # Validation.
    y_hats = model.predict(X_val)
    # Compute validation error.
    val_loss = mean_squared_error(y_val.values.flatten(), y_hats)
    val_losses_h[h+1] = val_loss
# Out:
# Training and validation for prediction horizon: 1
# Training and validation for prediction horizon: 2
# Training and validation for prediction horizon: 3
# Training and validation for prediction horizon: 4
# Training and validation for prediction horizon: 5
# Training and validation for prediction horizon: 6
# Training and validation for prediction horizon: 7
# Training and validation for prediction horizon: 8
# Training and validation for prediction horizon: 9
# Training and validation for prediction horizon: 10
# Training and validation for prediction horizon: 11
# Training and validation for prediction horizon: 12
# Training and validation for prediction horizon: 13
# Training and validation for prediction horizon: 14
# Training and validation for prediction horizon: 15
# Training and validation for prediction horizon: 16
# Training and validation for prediction horizon: 17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-912b5b4923b6> in <module>
#       8             X_train, y_train, X_val, y_val, _ = creator.to_supervised(n_out = TEST_SIZE, single_step = True, h = h+1, return_dataframe = True,
#       9                                                                       feature_time = True, validation = True, return_single_level = True,
# ---> 10                                                                       dtype = np.float32)
#      11             X_train_list.append(X_train)
#      12             y_train_list.append(y_train)
#
# ~\Desktop\ISI\ISI-WFP\project\packages\LagsCreator\LagsCreator.py in to_supervised(self, n_out, single_step, h, return_dataframe, validation, feature_time, return_single_level, dtype)
#     256                 y_val = y_val.astype(dtype)
#     257             # Define input samples test dataframes.
# --> 258             X_test, _ = self.to_dataframe(X_test, None)
#     259             # Change the type of the dataframe.
#     260             X_test = X_test.astype(dtype)
#
# ~\Desktop\ISI\ISI-WFP\project\packages\LagsCreator\LagsCreator.py in to_dataframe(self, X, y)
#     140                     # For the test samples.
#     141                     X.loc[0, ("Day", "x")] = (self.group.index[-1] + (self.h-1)*self.group.index.freq).day
# --> 142                     X.loc[0, ("Month", "x")] = (self.group.index[-1] + (self.h-1)*self.group.index.freq).month
#     143                     X.loc[0, ("Year", "x")] = (self.group.index[-1] + (self.h-1)*self.group.index.freq).year
#     144         else:
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     379                             indexer, self.obj.axes
#     380                         )
# --> 381                         self._setitem_with_indexer(new_indexer, value)
#     382
#     383                         return self.obj
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     555                 # scalar
#     556                 for item in labels:
# --> 557                     setter(item, value)
#     558
#     559         else:
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     487                     # set the item, possibly having a dtype change
#     488                     s._consolidate_inplace()
# --> 489                     s = s.copy()
#     490                     s._data = s._data.setitem(indexer=pi, value=v)
#     491                     s._maybe_update_cacher(clear=True)
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5994         dtype: object
#    5995         """
# -> 5996         data = self._data.copy(deep=deep)
#    5997         return self._constructor(data).__finalize__(self)
#    5998
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     786         else:
#     787             new_axes = list(self.axes)
# --> 788         return self.apply("copy", axes=new_axes, deep=deep, do_integrity_check=False)
#     789
#     790     def as_array(self, transpose=False, items=None):
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     769         values = self.values
#     770         if deep:
# --> 771             values = values.copy()
#     772         return self.make_block_same_class(values, ndim=self.ndim)
#     773
#
# KeyboardInterrupt:

# %%
val_losses_h
# Out:
# {1: 0.28121138,
#  2: 0.9905112,
#  3: 2.0189388,
#  4: 3.3603206,
#  5: 4.7964625,
#  6: 6.3696,
#  7: 8.07987,
#  8: 9.562505,
#  9: 11.854316,
#  10: 13.578206,
#  11: 15.36817,
#  12: 17.191833,
#  13: 18.321814,
#  14: 22.209806,
#  15: 24.07338,
#  16: 27.094795,
#  17: 31.21045,
#  18: 32.763477,
#  19: 33.91556,
#  20: 38.3616,
#  21: 40.759476,
#  22: 41.180992,
#  23: 46.210106,
#  24: 47.536396,
#  25: 50.85919,
#  26: 50.87438,
#  27: 51.137665,
#  28: 52.892708,
#  29: 49.80466,
#  30: 49.44041}

# %%
lags_dict
# Out:
# {'1 Month Anomaly (%) Rainfall': 2,
#  '3 Months Anomaly (%) Rainfall': 1,
#  'Cereals and tubers': 2,
#  'Exchange rate (USD/LCU)': 5,
#  'FCS': 2,
#  'Fatality': 2,
#  'NDVI Anomaly': 2,
#  'Rainfall (mm)': 2,
#  'rCSI': 2,
#  'Lat': 0,
#  'Lon': 0,
#  'Population': 0,
#  'Ramadan': 1}

# %%
creator = LagsCreator(TRAIN_NORMALIZED_SETS[0][["Abyan"]], lags_dictionary = lags_dict, target = "FCS")
X_train, y_train, X_val, y_val, _ = creator.to_supervised(n_out = TEST_SIZE, single_step = True, h = 30, return_dataframe = False,
                                                          feature_time = False, validation = True, return_single_level = True, 
                                                          dtype = np.float32)

# %%
train, val, test = creator.visualization()

# %%
df_styled = train[0]
html = df_styled.render()

# %%
html
# Out:
# '<style  type="text/css" >\n    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col0 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col1 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col2 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col3 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col4 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col5 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col6 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col7 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col8 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col9 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col10 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col11 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row0_col12 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col0 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col1 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col2 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col3 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col4 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col5 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col6 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col7 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col8 {\n            background-color:  RGBA(0,131,255,0.44);\n            background-color:  RGBA(0,131,255,0.44);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col9 {\n            background-color:  RGB(0,131,255);\n            background-color:  RGB(0,131,255);\n        }    #T_1a3c6954_c6c5_11ea_b0ab_8ca982f47233row1_col10 {\n            background-color: ...

# %%
import imgkit
from xvfbwrapper import Xvfb
vdisplay = Xvfb()
vdisplay.start()
imgkit.from_string(html, 'styled_df.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-59-c0362361d309> in <module>
#       1 import imgkit
# ----> 2 from xvfbwrapper import Xvfb
#       3 vdisplay = Xvfb()
#       4 vdisplay.start()
#       5 imgkit.from_string(html, 'styled_df.png')
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\xvfbwrapper.py in <module>
#      13 import tempfile
#      14 import time
# ---> 15 import fcntl
#      16 from random import randint
#      17
#
# ModuleNotFoundError: No module named 'fcntl'

# %%
import pdfkit
pdfkit.from_string('my_testpdf ABC','testpdf.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pdfkit\configuration.py in __init__(self, wkhtmltopdf, meta_tag_prefix)
#      20         try:
# ---> 21             with open(self.wkhtmltopdf) as f:
#      22                 pass
#
# FileNotFoundError: [Errno 2] No such file or directory: b''
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-61-5190d16e5be2> in <module>
#       1 import pdfkit
# ----> 2 pdfkit.from_string('my_testpdf ABC','testpdf.pdf')
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pdfkit\api.py in from_string(input, output_path, options, toc, cover, css, configuration, cover_first)
#      68
#      69     r = PDFKit(input, 'string', options=options, toc=toc, cover=cover, css=css,
# ---> 70                configuration=configuration, cover_first=cover_first)
#      71
#      72     return r.to_pdf(output_path)
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pdfkit\pdfkit.py in __init__(self, url_or_file, type_, options, toc, cover, css, configuration, cover_first)
#      40
#      41         self.source = Source(url_or_file, type_)
# ---> 42         self.configuration = (Configuration() if configuration is None
#      43                               else configuration)
#      44         try:
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\pdfkit\configuration.py in __init__(self, wkhtmltopdf, meta_tag_prefix)
#      25                           'If this file exists please check that this process can '
#      26                           'read it. Otherwise please install wkhtmltopdf - '
# ---> 27                           'https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf' % self.wkhtmltopdf)
#
# OSError: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
val[0]
# Out:
# <style  type="text/css" >
#     #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col0 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col1 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col2 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col4 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col5 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col6 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col7 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col8 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col9 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col10 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col11 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row139_col12 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col0 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col1 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col2 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col4 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col5 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col6 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col7 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col8 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col9 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col10 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col11 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row140_col12 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col0 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col1 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col2 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col4 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col5 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col6 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col7 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col8 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col9 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col10 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col11 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row141_col12 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col0 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col1 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col2 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col4 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col5 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col6 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col7 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col8 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col9 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col10 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col11 {
#             background-color:  RGBA(0,131,255,0.44);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row142_col12 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col0 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col1 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col2 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col4 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col5 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col6 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col7 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col8 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col9 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col10 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col11 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row143_col12 {
#             background-color:  RGB(0,131,255);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row145_col4 {
#             background-color:  RGB(255,154,0);
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row146_col4 {
#             color:  red;
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row147_col4 {
#             color:  red;
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row148_col4 {
#             color:  red;
#         }    #T_d0105de8_c6c2_11ea_9cb5_8ca982f47233row149_col4

# %%
test[0]
# Out:
# <style  type="text/css" >
#     #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row145_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row146_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row147_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row148_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row149_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row150_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row151_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row152_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row153_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row154_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row155_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row156_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row157_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row158_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row159_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row160_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row161_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row162_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row163_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row164_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row165_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row166_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row167_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row168_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row169_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row170_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row170_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row171_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row171_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row172_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row172_col4 {
#             color:  red;
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col0 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col2 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col4 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col5 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col8 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col10 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row173_col12 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col0 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col1 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col2 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col3 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col4 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col5 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col6 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col7 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col8 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col9 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col10 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col11 {
#             background-color:  RGB(0,131,255);
#         }    #T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row174_col12 {
#             background-color:  RGB(0,131,255);
#         }</style><table id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233" ><thead>    <tr>        <th class="index_name level0" >Indicator</th>        <th class="col_heading level0 col0" >1 Month Anomaly (%) Rainfall</th>        <th class="col_heading level0 col1" >3 Months Anomaly (%) Rainfall</th>        <th class="col_heading level0 col2" >Cereals and tubers</th>        <th class="col_heading level0 col3" >Exchange rate (USD/LCU)</th>        <th class="col_heading level0 col4" >FCS</th>        <th class="col_heading level0 col5" >Fatality</th>        <th class="col_heading level0 col6" >Lat</th>        <th class="col_heading level0 col7" >Lon</th>        <th class="col_heading level0 col8" >NDVI Anomaly</th>        <th class="col_heading level0 col9" >Population</th>        <th class="col_heading level0 col10" >Rainfall (mm)</th>        <th class="col_heading level0 col11" >Ramadan</th>        <th class="col_heading level0 col12" >rCSI</th>    </tr>    <tr>        <th class="index_name level0" >Datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233level0_row0" class="row_heading level0 row0" >2018-08-22 00:00:00</th>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col0" class="data row0 col0" >272.9966</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col1" class="data row0 col1" >329.8125</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col2" class="data row0 col2" >0.3282</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col3" class="data row0 col3" >0.3676</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col4" class="data row0 col4" >31.7605</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col5" class="data row0 col5" >11.0799</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col6" class="data row0 col6" >13.7049</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col7" class="data row0 col7" >46.1581</td>
#                         <td id="T_7009d2d2_c6c2_11ea_9b4c_8ca982f47233row0_col8" class="data row0 col8" >3051.979</td>
#                         <td id="
