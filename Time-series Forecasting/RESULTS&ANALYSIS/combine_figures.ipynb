# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
fig.subplots_adjust(wspace = .05)

image = mpimg.imread("./IMAGES/Analysis 2022 Same Time Length/all_countries.png")
axs[0].imshow(image, aspect="auto")
axs[0].set_axis_off()
axs[0].text(-0., .95, "a", transform = axs[0].transAxes, size = 15, weight = "bold")
image = mpimg.imread("./IMAGES/Analysis 2022 Same Nb Provinces/Figure4a.png")
axs[1].imshow(image, aspect="auto")
axs[1].set_axis_off()
axs[1].text(-0., .95, "b", transform = axs[1].transAxes, size = 15, weight = "bold")

fig.savefig(f"./IMAGES/panel_paper.png" , bbox_inches = "tight", dpi = 300)
