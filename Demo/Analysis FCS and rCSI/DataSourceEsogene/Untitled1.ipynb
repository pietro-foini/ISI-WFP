# %%
import pandas as pd
import numpy as np

# %%
price = pd.read_csv("wfp_food_prices_yemen.csv", header = 1)
price.head()
# Out:
#         #date            #item+name #item+unit          #item+type  #value  \
# 0  2016-07-15  Wheat flour - Retail         KG  cereals and tubers   172.0
# 1  2016-08-15  Wheat flour - Retail         KG  cereals and tubers   150.0
# 2  2016-09-15  Wheat flour - Retail         KG  cereals and tubers   150.0
# 3  2016-10-15  Wheat flour - Retail         KG  cereals and tubers   153.0
# 4  2016-11-15  Wheat flour - Retail         KG  cereals and tubers   164.0
#
#   #currency #country+name #adm1+name  #adm1+code   #name+market  Unnamed: 10  \
# 0       YER         Yemen      Abyan        3407  Zungubar City         1940
# 1       YER         Yemen      Abyan        3407  Zungubar City         1940
# 2       YER         Yemen      Abyan        3407  Zungubar City         1940
# 3       YER         Yemen      Abyan        3407  Zungubar City         1940
# 4       YER         Yemen      Abyan        3407  Zungubar City         1940
#
# ...
